# %%
def dy_dx(x):
  return 2*x

# %%
dy_dx(3)
# Out:
# 6

# %%
import torch

# %%
x = torch.tensor(3.0, requires_grad=True)       # if required_grad=True, that means Pytorch will create deviation of this tensor x

# %%
y = x**2       # z = sin y. so dz/dy = cos y = cos x**2

# %%
x
# Out:
# tensor(3., requires_grad=True)

# %%
y        # O/P shows backward calculation x --> sq --> y
# Out:
# tensor(9., grad_fn=<PowBackward0>)

# %%
# derivative of y = dy/dx. backward() is used to get derivation towards backward pass. dy/dx==2x
y.backward()

# %%
x.grad
# Out:
# tensor(6.)

# %%
import math

def dz_dx(x):
    return 2 * x * math.cos(x**2)

# %%
dz_dx(4)
# Out:
# -7.661275842587077

# %%
x = torch.tensor(4.0, requires_grad=True)

# %%
y = x ** 2

# %%
z = torch.sin(y)

# %%
x
# Out:
# tensor(4., requires_grad=True)

# %%
y
# Out:
# tensor(16., grad_fn=<PowBackward0>)

# %%
z
# Out:
# tensor(-0.2879, grad_fn=<SinBackward0>)

# %%
z.backward()

# %%
x.grad
# Out:
# tensor(-7.6613)

# %%
y.grad
# Out:
# /tmp/ipykernel_18202/486760323.py:1: UserWarning: The .grad attribute of a Tensor that is not a leaf Tensor is being accessed. Its .grad attribute won't be populated during autograd.backward(). If you indeed want the .grad field to be populated for a non-leaf Tensor, use .retain_grad() on the non-leaf Tensor. If you access the non-leaf Tensor by mistake, make sure you access the leaf Tensor instead. See github.com/pytorch/pytorch/pull/30531 for more informations. (Triggered internally at /pytorch/build/aten/src/ATen/core/TensorBody.h:489.)
#   y.grad

# %%
import torch

# Inputs
x = torch.tensor(6.7)  # Input feature
y = torch.tensor(0.0)  # True label (binary)

w = torch.tensor(1.0)  # Weight
b = torch.tensor(0.0)  # Bias

# %%
# Binary Cross-Entropy Loss for scalar
def binary_cross_entropy_loss(prediction, target):
    epsilon = 1e-8  # To prevent log(0)
    prediction = torch.clamp(prediction, epsilon, 1 - epsilon)
    return -(target * torch.log(prediction) + (1 - target) * torch.log(1 - prediction))

# %%
# Forward pass
z = w * x + b  # Weighted sum (linear part)
y_pred = torch.sigmoid(z)  # Predicted probability

# Compute binary cross-entropy loss
loss = binary_cross_entropy_loss(y_pred, y)

# %%
loss
# Out:
# tensor(6.7012)

# %%
# Derivatives:
# 1. dL/d(y_pred): Loss with respect to the prediction (y_pred)
dloss_dy_pred = (y_pred - y)/(y_pred*(1-y_pred))

# 2. dy_pred/dz: Prediction (y_pred) with respect to z (sigmoid derivative)
dy_pred_dz = y_pred * (1 - y_pred)

# 3. dz/dw and dz/db: z with respect to w and b
dz_dw = x  # dz/dw = x
dz_db = 1  # dz/db = 1 (bias contributes directly to z)

dL_dw = dloss_dy_pred * dy_pred_dz * dz_dw
dL_db = dloss_dy_pred * dy_pred_dz * dz_db

# %%
print(f"Manual Gradient of loss w.r.t weight (dw): {dL_dw}")
print(f"Manual Gradient of loss w.r.t bias (db): {dL_db}")
# Out:
# Manual Gradient of loss w.r.t weight (dw): 6.691762447357178
# Manual Gradient of loss w.r.t bias (db): 0.998770534992218

# %%
x = torch.tensor(6.7)
y = torch.tensor(0.0)

# %%
w = torch.tensor(1.0, requires_grad=True)
b = torch.tensor(0.0, requires_grad=True)

# %%
w
# Out:
# tensor(1., requires_grad=True)

# %%
b
# Out:
# tensor(0., requires_grad=True)

# %%
z = w*x + b
z
# Out:
# tensor(6.7000, grad_fn=<AddBackward0>)

# %%
y_pred = torch.sigmoid(z)
y_pred
# Out:
# tensor(0.9988, grad_fn=<SigmoidBackward0>)

# %%
loss = binary_cross_entropy_loss(y_pred, y)
loss
# Out:
# tensor(6.7012, grad_fn=<NegBackward0>)

# %%
loss.backward()

# %%
print(w.grad)
print(b.grad)
# Out:
# tensor(6.6918)
# tensor(0.9988)

# %%
# what is want to do this in vector data ( 1 dimensional matrix)

# %%
x = torch.tensor([1.0, 2.0, 3.0], requires_grad=True)

# %%
x
# Out:
# tensor([1., 2., 3.], requires_grad=True)

# %%
y = (x**2).mean()
y
# Out:
# tensor(4.6667, grad_fn=<MeanBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor([0.6667, 1.3333, 2.0000])

# %%
# clearing grad
x = torch.tensor(2.0, requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y = x ** 2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.)

# %%
x.grad.zero_()
# Out:
# tensor(0.)

# %%
# disable gradient tracking (Sometimes in big neural network we may not need backward computation, so we will disable it)
x = torch.tensor(2.0, requires_grad=True)
x
# Out:
# tensor(2., requires_grad=True)

# %%
y = x ** 2
y
# Out:
# tensor(4., grad_fn=<PowBackward0>)

# %%
y.backward()

# %%
x.grad
# Out:
# tensor(4.)

# %%
# option 1 - requires_grad_(False)
# option 2 - detach()
# option 3 - torch.no_grad()

# %%
x.requires_grad_(False)         # used inplace function by adding _ in the function. This way parameter requires_grad=False
# Out:
# tensor(2.)

# %%
x
# Out:
# tensor(2.)

# %%
y = x ** 2

# %%
y
# Out:
# tensor(4.)

# %%
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 y.backward()
#
# File ~/pytorch_tutorial/venv/lib/python3.10/site-packages/torch/_tensor.py:648, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     638 if has_torch_function_unary(self):
#     639     return handle_torch_function(
#     640         Tensor.backward,
#     641         (self,),
#    (...)
#     646         inputs=inputs,
#     647     )
# --> 648 torch.autograd.backward(
#     649     self, gradient, retain_graph, create_graph, inputs=inputs
#     650 )
#
# File ~/pytorch_tutorial/venv/lib/python3.10/site-packages/torch/autograd/__init__.py:353, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     348     retain_graph = create_graph
#     350 # The reason we repeat the same comment below is that
# ...

# %%
x = torch.tensor(2.0, requires_grad=True)
x

# %%
z = x.detach()
z

# %%
y = x ** 2

# %%
y

# %%
y1 = z ** 2
y1

# %%
y.backward()

# %%
y1.backward()

# %%
x = torch.tensor(2.0, requires_grad=True)
x

# %%
y = x ** 2

# %%
y

# %%
y.backward()

# %%
# use no_grad() with statement
with torch.no_grad():
  y = x ** 2

# %%
y.backward()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 y.backward()
#
# File ~/pytorch_tutorial/venv/lib/python3.10/site-packages/torch/_tensor.py:648, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     638 if has_torch_function_unary(self):
#     639     return handle_torch_function(
#     640         Tensor.backward,
#     641         (self,),
#    (...)
#     646         inputs=inputs,
#     647     )
# --> 648 torch.autograd.backward(
#     649     self, gradient, retain_graph, create_graph, inputs=inputs
#     650 )
#
# File ~/pytorch_tutorial/venv/lib/python3.10/site-packages/torch/autograd/__init__.py:353, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     348     retain_graph = create_graph
#     350 # The reason we repeat the same comment below is that
# ...
